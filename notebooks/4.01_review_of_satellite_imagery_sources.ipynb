# %%
from IPython.display import Image

# %% [markdown]
# # Review of satellite imagery sources
#
# This week the focus will be on obtaining satellite imagery, and evaluating the quality and comprehensiveness of what is available.
#
# In this tutorial we will cover:
#
# - Sources of satellite imagery
# - Basic Graphical User Interface (GUI) tools to compare satellite imagery
# - The different types of processed satellite imagery
# - How to extract satellite imagery manually
#
# Future tutorials will be exclusively dedicated to scripting via Application Programming Interfaces (APIs), as this will require greater explanation (focusing on Sentinel-2, Planet Labs etc.).

# %% [markdown]
# ## Learning outcomes
#
# A key part of utilizing satellite imagery in this class is:
#
# - Having a good understanding of the different imagery sources available to you.
# - Being able to explain differences in the various types of imagery.
# - Understanding the strengths and weaknesses of using heterogenous imagery sources (and being able to reflect on the nuances of their respective methodologies).
#
# The emphasis here is on thinking critically about:
#
# - The sources of data available to you (e.g. Landsat vs Planet va Sentinel-2).
# - What various data sources represent and their characteristics (spatial and temporal resolution).
# - The strengths and weaknesses of using different methodologies (e.g., in terms of image collection, processing and use).
#
# You will need to be able to critically review your method in the final coursework project, and this will often be dependent on the imagery you use. Indeed, no method is perfect. There are always strengths and weakenesses, you need to merely be aware of them and articulate these aspects.
#
# Therefore, to score well you do not need to present a 'perfect method'. Instead, you must just recognize why one approach may be better than another for a certain problem, and then later in the paper discussion consider the method limitations.

# %% [markdown]
# ## Sources of satellite imagery

# %% [markdown]
# Satellite imagery is going through a period of tremendous change.
#
# This is driven by (i) a huge increase in the number of satellites, and (ii) in their technical capabilities (resolution, bands etc.).
#
# Over the past couple of decades, merely having satellite imagery to utilize at the global scale has been sufficient to satisfy a range of innovative uses of this data, including:
#
# - Globally-harmonized building outline datasets.
# - Globally-harmonized road network outline datasets.
# - Globally-harmonized population datasets (e.g., at the 1 km^2 level, such as WorldPop).
#
# More recently, with the densification of new constellations (e.g., Planet, Blacksky etc.) this leads to a dramatic increase in revisitation rates compared to a decade ago. This means we have much more frequent information on changes taking places across Earth, to support decisions.
#
# See the slide below from Anusuya Datta on the new age of satellite imagery (GIJN PPT Satellite imagery for journalism)

# %%
Image("images/Anusuya Datta - GIJN PPT Satellite imagery for journalism.png")

# Credit to 
# https://docs.google.com/presentation/d/10HUsFwmWBGYc8JaqVI4wH1j2xrzqu671076uXTZks8U/edit#slide=id.p1

# %% [markdown]
# There are many sources of free satellite imagery for you to explore!
#
# You should familiarize yourself with these different sources. Most here provide a Graphical User Interface (GUI) and an API:
#
# - Planet Platform: https://www.planet.com/get-started/
# - Sentinel Open Access Hub: https://scihub.copernicus.eu/
# - NASA Earthdata Search: https://search.earthdata.nasa.gov/search
# - NOAA Digital Coast: https://coast.noaa.gov/dataviewer/#/
# - DigitalGlobe Open Data Program: https://www.maxar.com/open-data
# - NASA Worldview: https://worldview.earthdata.nasa.gov/
# - NOAA CLASS: https://www.avl.class.noaa.gov/saa/products/welcome;jsessionid=9367946EC11615A8E96732F04022DAB2
# - USGS Earth Explorer: https://earthexplorer.usgs.gov/
# - Bhuvan Indian Geo-Platform of ISRO (IDN): https://bhuvan.nrsc.gov.in/home/index.php
# - JAXA’s Global ALOS 3D World (JPN): https://www.eorc.jaxa.jp/ALOS/en/index_e.htm
# - National Institute for Space Research (INPE) (BRA): http://www.dgi.inpe.br/DIDGI

# %% [markdown]
# ### Determining which images you should access/use
#
# One of the main challenges you will face is whether you:
#
# - Need access to the raw images (which you will need for this class).
# - Want open-source images (advisable).
# - Are resricted by the resolution and bands you require.
# - Require a certain temporal resolution or time period.

# %%
Image("images/flowchart.jpg")

# Credit to Joe Morrison
# https://www.azavea.com/blog/2020/01/02/how-to-find-the-most-recent-satellite-imagery/

# %% [markdown]
# ## Missions - Landsat
#
# Landsat is the longest satellite imagery program in existence.
#
# The first mission was in 1972 named the Earth Resources Technology Satellite (eventually renamed Landsat 1).
#
# Virginia Tower Norwood was responsible for designing the multispectral scanner (4 bands) placed onboard the first five Landsat missions.
#
# Norwood is often called the 'Mother of Landsat'.
#
# - 68x68 meter resolution.
# - 0.5-1.1 µm spectral range.
# - Temporal resolution: 18 days (L1-L3) and 16 days (L4 & L5).
# - 185x185 km image size.

# %%
Image("images/norwood.png")

# %% [markdown]
# Since then there have been many launches of new assets including:
#
# - Landsat 1 launched in 1972-1978
# - Landsat 2 launched in 1975-1982
# - Landsat 3 launched in 1978-1983
# - Landsat 4 launched in 1982-1993
# - Landsat 5 launched in 1984-2013
# - Landsat 6 launched in 1993-1993
# - Landsat 7 launched in 1999-2022
# - Landsat 8 launched in 2013-ongoing
# - Landsat 9 launched in 2021-ongoing

# %%
Image("images/landsat_timeline.png")

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/gfUYFPWYwXI?si=A1d16CJcpR6rUA5k" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/gfUYFPWYwXI?si=A1d16CJcpR6rUA5k" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ## Missions - Sentinel
#
# The Sentinel missions are a set of Earth Observation (EO) satellites launched on behalf of the joint European Space Agency (ESA)/European Commission initiative Copernicus.
#
# A range of EO topics are focused on for each of the missions, including Atmospheric, Oceanic, and Land monitoring.
#
# See the family of satellites illustrated below, from Sentinel 1 to 6:

# %%
Image("images/sentinel_family.jpg")

# %% [markdown]
# - **Sentinel-1**
# is a polar-orbiting, all-weather, **day-and-night radar imaging mission for land and ocean services**. Sentinel-1A was launched on 3 April 2014 and Sentinel-1B on 25 April 2016. Both were taken into orbit on a Soyuz rocket from Europe's Spaceport in French Guiana. The mission ended for Sentinel-1B in 2022 and plans are in force to launch Sentinel-1C as soon as possible.
#
# - **Sentinel-2** is a polar-orbiting, **multispectral high-resolution imaging mission for land monitoring** to provide, for example, imagery of vegetation, soil and water cover, inland waterways and coastal areas. Sentinel-2 can also deliver information for emergency services. Sentinel-2A was launched on 23 June 2015 and Sentinel-2B followed on 7 March 2017.
#
# - **Sentinel-3** is a **multi-instrument mission to measure sea-surface topography, sea- and land-surface temperature, ocean colour and land colour** with high-end accuracy and reliability. The mission supports ocean forecasting systems, as well as environmental and climate monitoring. Sentinel-3A was launched on 16 February 2016 and Sentinel-3B joined its twin in orbit on 25 April 2018.
#
# - **Sentinel-5 Precursor** – also known as Sentinel-5P – is the forerunner of Sentinel-5 to provide timely data on a **multitude of trace gases and aerosols affecting air quality and climate**. It has been developed to reduce data gaps between the Envisat satellite – in particular the Sciamachy instrument – and the launch of Sentinel-5. Sentinel-5P was taken into orbit on 13 October 2017 on a Rockot launcher from the Plesetsk Cosmodrome in northern Russia.
#
# - **Sentinel-4** is a payload devoted to **atmospheric monitoring** that will be embarked upon a Meteosat Third Generation-Sounder (MTG-S) satellite in geostationary orbit.
#
# - **Sentinel-5** is a payload that will monitor the **atmosphere from polar orbit** aboard a MetOp Second Generation satellite.
#
# - **Sentinel-6** carries a **radar altimeter to measure global sea-surface height, primarily for operational oceanography and for climate studies**. The first satellite was launched into orbit on 21 November 2020 on a SpaceX Falcon 9 rocket from the Vandenberg Air Force Base in California, US.

# %%
Image("images/sentinel_specs.png")

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/W3fv7TUmqf8?si=HAS29n_Gr0f2WIt8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/W3fv7TUmqf8?si=HAS29n_Gr0f2WIt8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7BKtN5Y_I7g?si=y7Da2LbRgUM21N0f" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7BKtN5Y_I7g?si=y7Da2LbRgUM21N0f" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ## Accessible sources of imagery
#
# Today we will tour various sources of imagery using the available GUIs, including:
# - Zoom Earth
# - World Imagery Wayback
# - Sentinel Hub
# - Planet Platform (if you've managed to sign up for your educational account)

# %% [markdown]
# ## Zoom Earth
# Visit the Zoom Earth (https://zoom.earth/)
#
# Familiarize yourself with the navigation and functionality panels which include:
#
# - The search bar which can help you find a desired location, or indeed active tropical storms or wildfires.
# - The information panel which details many of the sources of data which the service utilizes.
# - The settings available for parameterization, relating to either the units in use or the desired time/timezone.
# - Also examine the heat and fire button in the bottom right-hand corner of the Graphical User Interface (GUI) which draws in information from the NASA Fire Information for Resource Management System (FIRMS).
# - There is also a wind button which provides an animation of wind speed by location and point in time.

# %% [markdown]
# ## Exercise
#
# Firstly, carry out the following:
#
# - Explore Zoom Earth, particularly the navigation and functionality panels.
# - Turn on/off and explore the wind animation.
# - Turn on/off and explore the radar-driven rain detection layer.
# - Turn on/off and explore the wildfire (and other sources of heat) detection layer.
#
# Secondly, use the available interface to analyze:
#
# - Examine the spatio-temporal development of Hurricane Idalia for ~August 29th - September 7th 2023. (https://en.wikipedia.org/wiki/Hurricane_Idalia). Use a 24hr simulation, for each day. Make sure you have the wind and rain detector layers active.
# - Use the heatmap layer to explore parts of South West Asia (otherwise known as the 'Middle East'). Specifically examine oil and gas flaring activities in the UAE, Qatar, Saudi Arabia etc.

# %% [markdown]
# ## World Imagery Wayback
#
# Navigate to the World Imagery Wayback portal: https://livingatlas.arcgis.com/wayback/
#
# Wayback is a digital archive, providing users with access to the different versions of ESRI World Imagery created over time.
#
# Each layer in the archive represents a snapshot of the entire World Imagery map, as it existed on the date it was published. Wayback currently provides access to all published versions of World Imagery, dating back to February 20, 2014. There is an ArcGIS Online item for every version which can be accessed directly from this app or within the Wayback Imagery group. The source code for this app is available on Github.
#
# As World Imagery is updated with more current imagery, new versions of the map are published. When and where updates occur, the previous imagery is replaced and is no longer visible. For many use cases, the new imagery is more desirable and typically preferred. Other times, however, the previous imagery may support use cases that the new imagery does not. In these cases, a user may need to access a previous version of World Imagery.
#
# Available versions of the World Imagery map are presented within a timeline and as layers in a list. Versions that resulted in local changes are highlighted in bold white, and the layer currently selected is highlighted in blue. Point and click on the map for additional imagery details within the selected layer. One or more layers can be added to a queue and pushed to a new ArcGIS Online web map.

# %% [markdown]
# ## Exercise
#
# - Select a location you want to investigate.
# - Navigate to the ‘Toggle Swipe Mode’ on the left hand panel.
# - Select the date you want imagery for on the left hand side.
# - Repeat for the right hand side.
# - Now navigate to explore the following locations. Reflect on the temporal changes, but also on the differences in imagery quality and other associated issues with imagery usage:
#     - Kutupalong, Bangladesh (e.g. 2014 vs 2020) (refugee camps).
#     - Zaatari, Jordan (e.g. 2014 vs 2021) (refugee camps).
#     - Mosul, Ninawa, Iraq (e.g. 2014 vs 2021) (ISIL occupation and consequential war).
#     - Aleppo, Syria (e.g. 2014 vs 2020) (Syrian civil war).

# %% [markdown]
# ## Sentinel Hub
#
# Visit Sentinel Hub and navigate to Sentinel Playground: https://www.sentinel-hub.com/
#
# Here you can access all Sentinel imagery, with many pre-processed options.
#
# Familiarize yourself with:
# - The navigation search bar in the top right-hand corner of the screen, along with the zoom in/out buttons.
# - The dataset selection button in the far top right-hand corner of the screen.
# - The image calendar in the top left-hand corner of the screen.
# - The image rendering panel.
# - The image effects panel.
# - The ability to export a developed image using the image ‘generate’ button.

# %% [markdown]
# ## Exercise
#
# - Choose a single geographic location and use sentinel hub to download and save up to 5 selected images which reflect different points in time.
# - The challenge is to find cloud free versions of those images.
# - Select a location where there may have been significant change.
# - You may choose to use these images in the course.
# - Evaluate the quality and extent of the imagery available.
# - Reflect on how manually intensive this process is, and consider other options for obtaining large quantities of images.

# %% [markdown]
# ## USGS EarthExplorer
#
# EarthExplorer (http://earthexplorer.usgs.gov) provides online search, browse display, data download, and exports of metadata to support scientists and users with access to earth science data from the archives of the U.S. Geological Survey (USGS).
#
# EarthExplorer provides an enhanced user interface using state-of-the art JavaScript libraries, Hypertext Preprocessor (PHP), and the advanced Oracle spatial engine.
#
# Key features in EarthExplorer include:
# - Fast, geospatial search engine
# - Map viewer for viewing overlay footprints and browse overlays
# - Simple, fast Graphical User Interface (GUI)
# - Data access tool to search and discover data
# - Textual query capability
# - Keyhole Markup Language (KML) export capability to interface with Google Earth
# - Save or export queries, results, and map overlay for reuse
# - Request on-demand products
# - Access to browse images from standard products
# - User authentication service for access to specialized datasets and tools
# - Standard product downloads
# - User notifications of new acquisitions and available products through subscription services
# - Updated software code base supporting JavaScript and PHP

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/eAmTxsg6ZYE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/eAmTxsg6ZYE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Exercise
#
# - Go to the USGS Earth Explorer.
# - In the Feature Name field, search 'Fairfax', and select the state as 'Virginia'.
# - Click 'Search' and then select Fairfax, VA, as the location.
# - Next, move to the 'Data Sets' tab and navigate in the list to:
#     - 'Landsat'
#     - 'Landsat Collection 2 Level-2'
#     - 'Landsat 8-9 OLI/TIRS C2 L2'
# - Now move to the 'Results' tab and select an image.
# - When the box opens, select 'Open In New Window'.
# - Click 'Download'.
# - Select the comprehensive product option 'Landsat Collection 2 Level-2 Product Bundle'.
# - Downloading may take a while, so leave it to complete.

# %% [markdown]
# ## Download, install and open images in ESRI / QGIS!
#
# In the meantime, make sure you have a GIS downloaded and installed on your machine. You can download Quantum GIS (QGIS) for free(!) from here:
#
# - https://www.qgis.org/en/site/
#
# You will need to have QGIS installed on their machine to be able to inspect imagery we download.
#
# Once installed:
# - Open QGIS.
# - Navigate to the file menu and then the folder where you have the image.
# - Drag and drop the file into the QGIS display area.
# - As there may be many files, if you are prompted to select one, just 'select all' and click okay.
# - The image should appear!
